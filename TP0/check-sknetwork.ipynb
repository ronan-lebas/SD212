# %% [markdown]
# # SD212: Graph Learning

# %% [markdown]
# # Check your environment with scikit-network

# %% [markdown]
# This notebook aims at checking that you can work with the [scikit-network](https://scikit-network.readthedocs.io/en/latest/index.html) package.

# %% [markdown]
# ## Installation

# %% [markdown]
# If you don't have scikit-network installed, run the following cell and restart the kernel.

# %%
# !pip install scikit-network

# %% [markdown]
# ## Import

# %%
from IPython.display import SVG

# %%
from sknetwork.data import karate_club, load_netset
from sknetwork.visualization import visualize_graph

# %% [markdown]
# ## Check

# %%
graph = karate_club(metadata=True)
adjacency = graph.adjacency
position = graph.position
labels = graph.labels

# %%
image = visualize_graph(adjacency, position, labels=labels)

# %%
SVG(image)

# %%
dataset = load_netset('openflights')
# Out:
# Downloading openflights from NetSet...
# Unpacking archive...
# Parsing files...
# Done.

# %%
dataset
# Out:
# {'adjacency': <3097x3097 sparse matrix of type '<class 'numpy.int64'>'
#  	with 36386 stored elements in Compressed Sparse Row format>,
#  'meta': {'name': 'openflights',
#   'description': 'Airports with daily number of flights between them.',
#   'source': 'https://openflights.org'},
#  'names': array(['Goroka Airport', 'Madang Airport', 'Mount Hagen Kagamuga Airport',
#         ..., 'Saumlaki/Olilit Airport', 'Tarko-Sale Airport',
#         'Alashankou Bole (Bortala) airport'], dtype='<U65'),
#  'position': array([[145.39199829,  -6.08168983],
#         [145.78900147,  -5.20707989],
#         [144.29600525,  -5.82678986],
#         ...,
#         [131.30599976,  -7.98860979],
#         [ 77.81809998,  64.93080139],
#         [ 82.3       ,  44.895     ]])}

# %%
adjacency = dataset.adjacency
position = dataset.position
names = dataset.names

# %%
names[:10]
# Out:
# array(['Goroka Airport', 'Madang Airport', 'Mount Hagen Kagamuga Airport',
#        'Nadzab Airport', 'Port Moresby Jacksons International Airport',
#        'Wewak International Airport', 'Narsarsuaq Airport',
#        'Godthaab / Nuuk Airport', 'Kangerlussuaq Airport',
#        'Thule Air Base'], dtype='<U65')

# %%
image = visualize_graph(adjacency, position, node_size=3, display_edges=False, 
                        height=300, width=500)

# %%
SVG(image)
